# %%
import pandas as pd
import os

# %%
data = pd.read_csv("uk_fin.csv",encoding= 'unicode_escape')

# %%
data.shape
# Out:
# (899, 15)

# %%
data.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     91.000000  91.000000  91.000000  91.000000  91.000000    91.000000
# mean       0.564044   0.804769   5.395604  -3.768967   0.780220     0.062821
# std        0.109517   0.144076   3.492465   1.940632   0.416392     0.049462
# min        0.310000   0.387000   0.000000 -10.965000   0.000000     0.025200
# 25%        0.509000   0.712500   2.000000  -4.858000   1.000000     0.036050
# 50%        0.557000   0.852000   5.000000  -3.327000   1.000000     0.046300
# 75%        0.630000   0.907000   8.500000  -2.460500   1.000000     0.069750
# max        0.868000   0.992000  11.000000  -0.877000   1.000000     0.375000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     91.000000         91.000000  91.000000  91.000000   91.000000
# mean       0.162782          0.001834   0.222956   0.587242  123.585538
# ...

# %%
boxplot = data.boxplot(column=['danceability', 'energy', 'key','loudness','mode','speechiness'])

# %%
bp2 = data.boxplot(column=['acousticness','instrumentalness','liveness','valence','tempo'])

# %%
data.mean(axis=0)
# Out:
# danceability          0.576361
# energy                0.763885
# key                   4.900000
# loudness             -4.920711
# mode                  0.709459
# speechiness           0.060807
# acousticness          0.205134
# instrumentalness      0.095393
# liveness              0.198531
# valence               0.567679
# tempo               128.053141
# duration_s          253.924108
# dtype: float64

# %%
data.std(axis=0)
# Out:
# danceability         0.117924
# energy               0.191761
# key                  3.360319
# loudness             2.972689
# mode                 0.454319
# speechiness          0.041613
# acousticness         0.258969
# instrumentalness     0.263509
# liveness             0.136814
# valence              0.215352
# tempo               27.958950
# duration_s          50.878392
# dtype: float64

# %%
histogram = data.hist(column=['acousticness','instrumentalness','liveness','valence','tempo'])

# %%
hist2 = data.hist(column=['danceability', 'energy', 'key','loudness','mode','speechiness'])

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
df = pd.read_csv("japan_fin.csv")

# %%
plt.figure(figsize=(9,8))
sns.distplot(df['danceability'],color='b',bins=100, hist_kws={'alpha':0.4})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 14 columns):
# track_name          740 non-null object
# artist              740 non-null object
# danceability        740 non-null float64
# energy              740 non-null float64
# key                 740 non-null int64
# loudness            740 non-null float64
# mode                740 non-null int64
# speechiness         740 non-null float64
# acousticness        740 non-null float64
# instrumentalness    740 non-null float64
# liveness            740 non-null float64
# valence             740 non-null float64
# tempo               740 non-null float64
# duration_s          740 non-null float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 81.1+ KB

# %%
col_names = ['danceability', 'energy', 'key', 'loudness',
     'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo']
df_num = df[col_names]

# %%
df_num.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.559   0.330    9    -8.251     1       0.0285        0.8920
# 1         0.720   0.748   11    -4.468     0       0.0464        0.0124
# 2         0.750   0.727    5    -4.210     0       0.1420        0.0189
# 3         0.638   0.831    5    -3.944     1       0.1820        0.0281
# 4         0.734   0.766    1    -4.485     1       0.0383        0.0250
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000000    0.0975    0.285  135.109
# 1          0.000000    0.3120    0.614  128.008
# 2          0.000000    0.2660    0.359  129.993
# 3          0.000003    0.2770    0.685  175.038
# 4          0.001380    0.1080    0.600  127.986

# %%
df_num.hist(figsize=(16,20), bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AAC0C47710>,
# ...
#       dtype=object)
