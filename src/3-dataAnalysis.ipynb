# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().magic('matplotlib inline')

# %%
us11=pd.read_csv("usMerged.csv")
us12=pd.read_csv("us12.csv")
us13=pd.read_csv("us13.csv")
us14=pd.read_csv("us14.csv")
us15=pd.read_csv("us15.csv")
us16=pd.read_csv("us16.csv")
us17=pd.read_csv("us17.csv")
us18=pd.read_csv("us18.csv")
us19=pd.read_csv("us19.csv")

aus11=pd.read_csv("au11.csv")
aus12=pd.read_csv("au12.csv")
aus13=pd.read_csv("au13.csv")
aus14=pd.read_csv("au14.csv")
aus15=pd.read_csv("au15.csv")
aus16=pd.read_csv("au16.csv")
aus17=pd.read_csv("au17.csv")
aus18=pd.read_csv("au18.csv")
aus19=pd.read_csv("au19.csv")

us11.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count    892.000000  892.000000  892.000000  892.000000  892.000000
# mean       0.669716    0.673481    5.489910   -5.842622    0.632287
# std        0.136190    0.159161    3.662365    3.182187    0.482453
# min        0.000000    0.000000    0.000000  -60.000000    0.000000
# 25%        0.589000    0.568000    2.000000   -6.762250    0.000000
# 50%        0.677000    0.697000    6.000000   -5.465000    1.000000
# 75%        0.759000    0.795000    9.000000   -4.388500    1.000000
# max        0.964000    0.972000   11.000000   -1.844000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   892.000000    892.000000        892.000000  892.000000  892.000000
# mean      0.100900      0.144757          0.003675    0.171752    0.499609
# std       0.094822      0.189981          0.034883    0.125697    0.216822
# ...

# %%
df=pd.read_csv("uk_means.csv", encoding="unicode_escape") #red
df2=pd.read_csv("japan_means.csv") #green 
df3=pd.read_csv("usSummary.csv") #blue
df4=pd.read_csv("ausSummary.csv") #yellow

plt.figure(1, figsize=(20, 10),)

plt.subplot(331)
sns.distplot(df4.tempo, color= "y");
sns.distplot(df3.tempo, color= "b");
sns.distplot(df2.tempo, color= "g");
sns.distplot(df.tempo, color="r");
plt.xlabel('Tempo (bpm)', fontsize=18)
plt.grid(True)

plt.subplot(332)
sns.distplot(df4['liveness'], color= "y");
sns.distplot(df3['liveness'], color= "b");
sns.distplot(df2['liveness'], color= "g");
sns.distplot(df['liveness'], color="r");
plt.xlabel('Liveness', fontsize=18)
plt.grid(True)

plt.subplot(333)
sns.distplot(df4.energy, color= "y");
sns.distplot(df3.energy, color= "b");
sns.distplot(df2.energy, color= "g");
sns.distplot(df.energy, color= "r");
plt.xlabel('Energy', fontsize=18)
plt.grid(True)

plt.subplot(334)
sns.distplot(df4.loudness, color= "y");
sns.distplot(df3.loudness, color= "b");
sns.distplot(df2.loudness, color= "g");
sns.distplot(df.loudness, color="r");
plt.xlabel('Loudness  ', fontsize=18)
plt.grid(True)

plt.subplot(335)
sns.distplot(df4.danceability, color= "y");
sns.distplot(df3.danceability, color= "b");
sns.distplot(df2.danceability, color= "g");
sns.distplot(df.danceability, color= "r");
plt.xlabel('Danceability ', fontsize=18)
plt.grid(True)

plt.subplot(336)
sns.distplot(df4.valence, color= "y");
sns.distplot(df3.valence, color= "b");
sns.distplot(df2.valence, color= "g");
sns.distplot(df.valence, color= "r");
plt.xlabel('Valence', fontsize=18)
plt.grid(True)

plt.subplot(337)
sns.distplot(df4.acousticness, color= "y");
sns.distplot(df3.acousticness, color= "b");
sns.distplot(df2.acousticness, color= "g");
sns.distplot(df.acousticness, color= "r");
plt.xlabel('Acousticness', fontsize=18,)
plt.grid(True)

plt.subplot(338)
sns.distplot(df4.speechiness, color= "y");
sns.distplot(df3.speechiness, color= "b");
sns.distplot(df2.speechiness, color= "g");
sns.distplot(df.speechiness, color= "r");
plt.xlabel('Speechiness', fontsize=18)
plt.grid(True)

plt.subplot(339)
sns.distplot(df4.instrumentalness, color= "y");
sns.distplot(df3.instrumentalness, color= "b");
sns.distplot(df2.instrumentalness, color= "g");
sns.distplot(df.instrumentalness, color= "r");
plt.xlabel('Instrumentalness', fontsize=18)
plt.grid(True)

plt.tight_layout(pad=0.5, w_pad=0.6, h_pad=1.0)

# %%
boxplot=us11.boxplot(column=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness'])

# %%
df4
# Out:
#    year  danceability    energy       key  loudness      mode  speechiness  \
# 0  2011      0.655200  0.776030  5.460000 -4.781530  0.600000     0.084241
# 1  2012      0.636630  0.778870  4.680000 -4.846900  0.640000     0.085165
# 2  2013      0.626590  0.723080  5.320000 -5.395570  0.640000     0.077661
# 3  2014      0.647505  0.715081  5.111111 -5.553939  0.626263     0.076661
# 4  2015      0.657792  0.671865  4.739583 -5.866469  0.583333     0.074423
# 5  2016      0.669010  0.669643  5.234694 -5.815827  0.520408     0.092371
# 6  2017      0.670763  0.645871  5.193548 -5.740720  0.623656     0.084060
# 7  2018      0.661580  0.661200  4.840000 -5.704670  0.660000     0.098105
# 8  2019      0.682100  0.607480  5.290000 -6.263050  0.580000     0.098954
#
#    acousticness  instrumentalness  liveness   valence       tempo  duration_s
# 0      0.084578          0.026031  0.197583  0.592726  126.954840  232.188810
# ...

# %%
bp2=us11.boxplot(['acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])

# %%
m11=us11.mean(axis=0)
m12=us12.mean(axis=0)
m13=us13.mean(axis=0)
m14=us14.mean(axis=0)
m15=us15.mean(axis=0)
m16=us16.mean(axis=0)
m17=us17.mean(axis=0)
m18=us18.mean(axis=0)
m19=us19.mean(axis=0)

am11=aus11.mean(axis=0)
am12=aus12.mean(axis=0)
am13=aus13.mean(axis=0)
am14=aus14.mean(axis=0)
am15=aus15.mean(axis=0)
am16=aus16.mean(axis=0)
am17=aus17.mean(axis=0)
am18=aus18.mean(axis=0)
am19=aus19.mean(axis=0)

# %%
usSummary= pd.DataFrame(columns=["year","danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness",
                                "liveness", "valence", "tempo", "duration_s"])

usSummary=usSummary.append(m11, ignore_index=True)
usSummary.loc[0, 'year']='2011'

usSummary=usSummary.append(m12, ignore_index=True)
usSummary.loc[1, 'year']='2012'

usSummary=usSummary.append(m13, ignore_index=True)
usSummary.loc[2, 'year']='2013'

usSummary=usSummary.append(m14, ignore_index=True)
usSummary.loc[3, 'year']='2014'

usSummary=usSummary.append(m15, ignore_index=True)
usSummary.loc[4, 'year']='2015'

usSummary=usSummary.append(m16, ignore_index=True)
usSummary.loc[5, 'year']='2016'

usSummary=usSummary.append(m17, ignore_index=True)
usSummary.loc[6, 'year']='2017'

usSummary=usSummary.append(m18, ignore_index=True)
usSummary.loc[7, 'year']='2018'

usSummary=usSummary.append(m19, ignore_index=True)
usSummary.loc[8, 'year']='2019'

# %%
ausSummary= pd.DataFrame(columns=["year","danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness",
                                "liveness", "valence", "tempo", "duration_s"])

ausSummary=ausSummary.append(am11, ignore_index=True)
ausSummary.loc[0, 'year']='2011'

ausSummary=ausSummary.append(am12, ignore_index=True)
ausSummary.loc[1, 'year']='2012'

ausSummary=ausSummary.append(am13, ignore_index=True)
ausSummary.loc[2, 'year']='2013'

ausSummary=ausSummary.append(am14, ignore_index=True)
ausSummary.loc[3, 'year']='2014'

ausSummary=ausSummary.append(am15, ignore_index=True)
ausSummary.loc[4, 'year']='2015'

ausSummary=ausSummary.append(am16, ignore_index=True)
ausSummary.loc[5, 'year']='2016'

ausSummary=ausSummary.append(am17, ignore_index=True)
ausSummary.loc[6, 'year']='2017'

ausSummary=ausSummary.append(am18, ignore_index=True)
ausSummary.loc[7, 'year']='2018'

ausSummary=ausSummary.append(am19, ignore_index=True)
ausSummary.loc[8, 'year']='2019'

# %%
ausSummary
# Out:
#    year  danceability    energy       key  loudness      mode  speechiness  \
# 0  2011      0.655200  0.776030  5.460000 -4.781530  0.600000     0.084241
# 1  2012      0.636630  0.778870  4.680000 -4.846900  0.640000     0.085165
# 2  2013      0.626590  0.723080  5.320000 -5.395570  0.640000     0.077661
# 3  2014      0.647505  0.715081  5.111111 -5.553939  0.626263     0.076661
# 4  2015      0.657792  0.671865  4.739583 -5.866469  0.583333     0.074423
# 5  2016      0.669010  0.669643  5.234694 -5.815827  0.520408     0.092371
# 6  2017      0.670763  0.645871  5.193548 -5.740720  0.623656     0.084060
# 7  2018      0.661580  0.661200  4.840000 -5.704670  0.660000     0.098105
# 8  2019      0.682100  0.607480  5.290000 -6.263050  0.580000     0.098954
#
#    acousticness  instrumentalness  liveness   valence       tempo  duration_s
# 0      0.084578          0.026031  0.197583  0.592726  126.954840  232.188810
# ...

# %%
usSummary.to_csv("usSummary.csv", index=False, encoding='utf8')
ausSummary.to_csv("ausSummary.csv", index=False, encoding='utf8')

# %%
us11.std(axis=0)
# Out:
# danceability         0.136190
# energy               0.159161
# key                  3.662365
# loudness             3.182187
# mode                 0.482453
# speechiness          0.094822
# acousticness         0.189981
# instrumentalness     0.034883
# liveness             0.125697
# valence              0.216822
# tempo               28.789510
# duration_s          35.349832
# dtype: float64

# %%
histogram=us11.hist(column=['acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])

# %%
histogram=us11.hist(column=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness'])

# %%
plt.figure(1, figsize=(10, 5),)

plt.subplot(331)
sns.distplot(us11.tempo);
plt.text(10, .010, r'$\mu=\ 121.12$', fontsize=22)
plt.xlabel('Tempo (BMP)')
plt.grid(True)

plt.subplot(332)
sns.distplot(us11.key);
plt.text(70, .020, r'$\mu=\ 30.51$', fontsize=22)
plt.xlabel('Popularity', fontsize=18, **hfont)
plt.grid(True)

plt.subplot(333)
sns.distplot(us11.energy);
plt.text(85, .010, r'$\mu=\ 52.05$', fontsize=22)
plt.xlabel('Energy')
plt.grid(True)

plt.subplot(334)
sns.distplot(us11.loudness);
plt.text(-30, 0.10, r'$\mu=\ -9.36$', fontsize=22)
plt.xlabel('Loudness')
plt.grid(True)

plt.subplot(335)
sns.distplot(us11.danceability);
plt.text(70, 0.02, r'$\mu=\ 47.38$', fontsize=22)
plt.xlabel('Danceability')
plt.grid(True)

plt.subplot(336)
sns.distplot(us11.valence);
plt.text(80, 0.01, r'$\mu=\ 40.68$', fontsize=22)
plt.xlabel('Valence (positive mood)')
plt.grid(True)

plt.subplot(337)
sns.distplot(us11.instrumentalness);
plt.text(80, 0.02, r'$\mu=\ 40.46$', fontsize=22)
plt.xlabel('Instrumentalness')
plt.grid(True)

plt.subplot(337)
sns.distplot(us11.liveness);
plt.text(80, 0.02, r'$\mu=\ 40.46$', fontsize=22)
plt.xlabel('Liveness')
plt.grid(True)

plt.subplot(337)
sns.distplot(us11.acousticness);
plt.text(80, 0.02, r'$\mu=\ 40.46$', fontsize=22)
plt.xlabel('Acousticness')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5220ad5abf16> in <module>
#      10 sns.distplot(us11.key);
#      11 plt.text(70, .020, r'$\mu=\ 30.51$', fontsize=22)
# ---> 12 plt.xlabel('Popularity', fontsize=18, **hfont)
#      13 plt.grid(True)
#      14
#
# NameError: name 'hfont' is not defined

# %%
us11
# Out:
#                                             track_name           artist  \
# 0                                  Rolling in the Deep            Adele
# 1                                    Party Rock Anthem            LMFAO
# 2                                             Firework       Katy Perry
# 3                                                 E.T.       Katy Perry
# 4    Give Me Everything (feat. Ne-Yo, Afrojack & Na...          Pitbull
# ..                                                 ...              ...
# 887                                    One Number Away       Luke Combs
# 888            Powerglide (feat. Juicy J) - From SR3MM     Rae Sremmurd
# 889                                              IDGAF         Dua Lipa
# 890                           Mi Gente (feat. Beyoncé)         J Balvin
# 891                                           Believer  Imagine Dragons
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
plt.figure(1, figsize=(10, 5),)

plt.subplot(331)
sns.distplot(usSummary.tempo);
plt.text(10, .010, r'$\mu=\ 121.12$', fontsize=22)
plt.xlabel('Tempo (BMP)')
plt.grid(True)

plt.subplot(332)
sns.distplot(usSummary.key);
plt.text(70, .020, r'$\mu=\ 30.51$', fontsize=22)
plt.xlabel('Popularity', fontsize=18, **hfont)
plt.grid(True)

plt.subplot(333)
sns.distplot(usSummary.energy);
plt.text(85, .010, r'$\mu=\ 52.05$', fontsize=22)
plt.xlabel('Energy')
plt.grid(True)

plt.subplot(334)
sns.distplot(usSummary.loudness);
plt.text(-30, 0.10, r'$\mu=\ -9.36$', fontsize=22)
plt.xlabel('Loudness')
plt.grid(True)

plt.subplot(335)
sns.distplot(usSummary.danceability);
plt.text(70, 0.02, r'$\mu=\ 47.38$', fontsize=22)
plt.xlabel('Danceability')
plt.grid(True)

plt.subplot(336)
sns.distplot(usSummary.valence);
plt.text(80, 0.01, r'$\mu=\ 40.68$', fontsize=22)
plt.xlabel('Valence (positive mood)')
plt.grid(True)

plt.subplot(337)
sns.distplot(usSummary.instrumentalness);
plt.text(80, 0.02, r'$\mu=\ 40.46$', fontsize=22)
plt.xlabel('Instrumentalness')
plt.grid(True)

plt.subplot(337)
sns.distplot(usSummary.liveness);
plt.text(80, 0.02, r'$\mu=\ 40.46$', fontsize=22)
plt.xlabel('Liveness')
plt.grid(True)

plt.subplot(337)
sns.distplot(usSummary.acousticness);
plt.text(80, 0.02, r'$\mu=\ 40.46$', fontsize=22)
plt.xlabel('Acousticness')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4209ff3db33f> in <module>
#      10 sns.distplot(usSummary.key);
#      11 plt.text(70, .020, r'$\mu=\ 30.51$', fontsize=22)
# ---> 12 plt.xlabel('Popularity', fontsize=18, **hfont)
#      13 plt.grid(True)
#      14
#
# NameError: name 'hfont' is not defined

# %%
usSummary['year']=usSummary['year'].astype(float)
sns.jointplot(y=us11['tempo'], x=us11['acousticness'], kind="hex", color="r", size=13).set_axis_labels("acousticness", "tempo", fontsize=35)

# %%
us112=us11.drop(['track_name', 'artist'], axis=1)
aus112=aus11.drop(['track_name', 'artist'], axis=1)

# %%
aus112
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.752   0.727    5    -4.161     0       0.1600       0.02460
# 1          0.697   0.791    2    -8.140     0       0.0330       0.00293
# 2          0.723   0.758    9    -4.418     1       0.0506       0.01750
# 3          0.554   0.321    9    -8.251     1       0.0280       0.89300
# 4          0.729   0.777    8    -5.112     1       0.0293       0.13000
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.718   0.810    0    -3.443     0       0.1060       0.23800
# 96         0.646   0.723    0    -4.829     0       0.0454       0.01260
# 97         0.652   0.748    0    -5.242     1       0.0887       0.08490
# 98         0.546   0.796    1    -3.263     1       0.0639       0.09090
# 99         0.739   0.818    8    -5.062     1       0.0418       0.00800
#
#     instrumentalness  liveness  valence    tempo  duration_s
# ...

# %%
from sklearn.manifold import TSNE
us11_embedded = TSNE(n_components=2).fit_transform(us112)

from sklearn.manifold import TSNE
us11_embedded = TSNE(n_components=2).fit_transform(us112)

# %%
from matplotlib.pyplot import *
fig = figure(figsize=(20, 20))
ax = axes(frameon=False)
setp(ax, xticks=(), yticks=())
subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                wspace=0.0, hspace=0.0)
scatter(us11_embedded[:, 0], us11_embedded[:, 1], s=80,   marker="8")

for row_id in range(0, len(us11)):
    #if (df.ARTIST[row_id] in ['The National']):
        target_word = us11.track_name[row_id]
        xx = us11_embedded[row_id, 0]
        yy = us11_embedded[row_id, 1]
        plt.annotate(target_word, (xx,yy), size=10, xytext=(-90,90), 
            textcoords='offset points', ha='center', va='bottom',
            bbox=dict(boxstyle='round4', fc='white', alpha=0.3),
            arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5', 
                            color='red'))

# %%
us112.corr()
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000  0.054977  0.073907 -0.036044 -0.256492
# energy                0.054977  1.000000  0.110464  0.627450 -0.127468
# key                   0.073907  0.110464  1.000000  0.103952 -0.119589
# loudness             -0.036044  0.627450  0.103952  1.000000  0.018152
# mode                 -0.256492 -0.127468 -0.119589  0.018152  1.000000
# speechiness          -0.240701  0.213055  0.067459 -0.117224 -0.065882
# acousticness         -0.125322 -0.583881 -0.048734 -0.371699  0.121567
# instrumentalness      0.125665  0.050709 -0.021669  0.004033 -0.219938
# liveness             -0.096893  0.206395  0.059520  0.130198 -0.070841
# valence               0.353999  0.494686  0.113234  0.328531 -0.078864
# tempo                -0.133590  0.084202  0.043167  0.096107 -0.064108
# duration_s           -0.252070 -0.140255 -0.000941 -0.152751  0.001112
#
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(aus112)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.78052801 0.21083272]

# %%
us11_pca = pca.fit_transform(aus112)

# %%
from sklearn import svm
clf = svm.OneClassSVM(kernel="rbf", gamma=0.001, nu=0.3)
clf.fit(us11_pca)
# Out:
# OneClassSVM(cache_size=200, coef0=0.0, degree=3, gamma=0.001, kernel='rbf',
#             max_iter=-1, nu=0.3, shrinking=True, tol=0.001, verbose=False)

# %%
xx, yy = np.meshgrid(np.linspace(-200, 800, 500), np.linspace(-200,800, 500))

Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(30, 20),)
#plt.title("Novelty Detection")
plt.contourf(xx, yy, Z, levels=np.linspace(Z.min(), 0, 7), cmap=plt.cm.Blues_r)
a = plt.contour(xx, yy, Z, levels=[0], linewidths=5, colors='red')
plt.contourf(xx, yy, Z, levels=[0, Z.max()], colors='orange')

#visualize song titles
'''
for row_id in range(0, len(df)):
    #if (df.ARTIST[row_id] in ['The National']):
        target_word = df.TITLE[row_id]
        xxx = x_pca[row_id, 0]
        yyy = x_pca[row_id, 1]
        plt.annotate(target_word, (xxx,yyy), size=10, xytext=(-90,90), 
            textcoords='offset points', ha='center', va='bottom',
            bbox=dict(boxstyle='round4', fc='white', alpha=0.3),
            arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5', 
                            color='red'))
'''   

b1 = plt.scatter(us11_pca[:, 0], us11_pca[:, 1], c='white', s=100)
plt.axis('tight')
plt.xlim((-200, 650))
plt.ylim((-150, 150))

leg = plt.legend([a.collections[0], b1, ],
           ["learned frontier", "training observations"],
           loc="upper left",prop={'size':30}, frameon=True)

plt.show()

# %%
plt.scatter(us11_pca[:, 0], us11_pca[:, 1])
