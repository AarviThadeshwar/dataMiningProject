# %%
import pandas as pd
import os

# %%
path_to_file="usa.csv"
path_to_file2="aus.csv"
data= pd.read_csv(path_to_file, encoding="utf-8")
data2=pd.read_csv(path_to_file2, encoding="utf-8")
print(type(data))
print(type(data2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data['duration_ms']=data['duration_ms'].div(1000)
data.rename({'first_artist':'artist', 'duration_ms':'duration_s'},axis=1, inplace=True)

data2['duration_ms']=data2['duration_ms'].div(1000)
data2.rename({'first_artist':'artist', 'duration_ms':'duration_s'},axis=1, inplace=True)

# %%
data
# Out:
#                  playlist_id  \
# 0     3IEcKuHVeXPPvG0UExRayu
# 1     3IEcKuHVeXPPvG0UExRayu
# 2     3IEcKuHVeXPPvG0UExRayu
# 3     3IEcKuHVeXPPvG0UExRayu
# 4     3IEcKuHVeXPPvG0UExRayu
# ...                      ...
# 1329  1Cizv5UZgLdCZhX6xGPoPm
# 1330  1Cizv5UZgLdCZhX6xGPoPm
# 1331  1Cizv5UZgLdCZhX6xGPoPm
# 1332  1Cizv5UZgLdCZhX6xGPoPm
# 1333  1Cizv5UZgLdCZhX6xGPoPm
#
#                                              track_name               artist  \
# 0                                   Rolling in the Deep                Adele
# 1                                     Party Rock Anthem                LMFAO
# 2                                              Firework           Katy Perry
# 3                                                  E.T.           Katy Perry
# 4     Give Me Everything (feat. Ne-Yo, Afrojack & Na...              Pitbull
# ...                                                 ...                  ...
# ...

# %%
us11full=data[data["playlist_id"]=="3IEcKuHVeXPPvG0UExRayu"]
us12full=data[data["playlist_id"]=="7xUFHJ6xYAGYsyBGe56jLa"]
us13full=data[data["playlist_id"]=="1RvbpP2tjOnM3WUKXU79Ia"]
us14full=data[data["playlist_id"]=="7kgzIK5Bx0i2klTIEtDOOH"]
us15full=data[data["playlist_id"]=="7mtNxdkGWfCCoG518Sfpnu"]
us16full=data[data["playlist_id"]=="6Z7eWArdZYW2OK3FEUEzEL"]
us17full=data[data["playlist_id"]=="1X4X3G0r6kPUWqfY1lOWMb"]
us18full=data[data["playlist_id"]=="5HR9CasBICVmt4rWswlRPR"]
us19full=data[data["playlist_id"]=="1Cizv5UZgLdCZhX6xGPoPm"]

au11full=data2[data2["playlist_id"]=="3FWGHF3qH1px8xRyTExPzj"]
au12full=data2[data2["playlist_id"]=="4SOo1A2IvAa3O07x0ZP1Xl"]
au13full=data2[data2["playlist_id"]=="6aSOcNZcerlphvP47Qkfkk"]
au14full=data2[data2["playlist_id"]=="5AkqpiqU0tSynN6ypS2Pnr"]
au15full=data2[data2["playlist_id"]=="3BIq6PAn5FOVi3KXPjQ6Mv"]
au16full=data2[data2["playlist_id"]=="4AM4P5gDwoOyibkUXfKxYW"]
au17full=data2[data2["playlist_id"]=="4fKgbFvvy1pE7qP5bdqWn7"]
au18full=data2[data2["playlist_id"]=="131Qux0az7RVLOoZqA4fd7"]
au19full=data2[data2["playlist_id"]=="4Sj7OVXe38RuiriXX2PKIg"]

# %%
au11full
# Out:
#                 playlist_id  \
# 0    3FWGHF3qH1px8xRyTExPzj
# 1    3FWGHF3qH1px8xRyTExPzj
# 2    3FWGHF3qH1px8xRyTExPzj
# 3    3FWGHF3qH1px8xRyTExPzj
# 4    3FWGHF3qH1px8xRyTExPzj
# ..                      ...
# 145  3FWGHF3qH1px8xRyTExPzj
# 146  3FWGHF3qH1px8xRyTExPzj
# 147  3FWGHF3qH1px8xRyTExPzj
# 148  3FWGHF3qH1px8xRyTExPzj
# 149  3FWGHF3qH1px8xRyTExPzj
#
#                                             track_name          artist  \
# 0                                    Party Rock Anthem           LMFAO
# 1    Somebody That I Used To Know - Miami Nights 19...           Gotye
# 2    Moves Like Jagger - Studio Recording From The ...        Maroon 5
# 3                                     Someone Like You           Adele
# 4                                  Rolling In The Deep           Adele
# ..                                                 ...             ...
# 145                                  Take Over Control        Afrojack
# ...

# %%
us11dups=us11full.drop_duplicates(subset=None, keep='first', inplace=False)
us12dups=us12full.drop_duplicates(subset=None, keep='first', inplace=False)
us13dups=us13full.drop_duplicates(subset=None, keep='first', inplace=False)
us14dups=us14full.drop_duplicates(subset=None, keep='first', inplace=False)
us15dups=us15full.drop_duplicates(subset=None, keep='first', inplace=False)
us16dups=us16full.drop_duplicates(subset=None, keep='first', inplace=False)
us17dups=us17full.drop_duplicates(subset=None, keep='first', inplace=False)
us18dups=us18full.drop_duplicates(subset=None, keep='first', inplace=False)
us19dups=us19full.drop_duplicates(subset=None, keep='first', inplace=False)

au11dups=au11full.drop_duplicates(subset=None, keep='first', inplace=False)
au12dups=au12full.drop_duplicates(subset=None, keep='first', inplace=False)
au13dups=au13full.drop_duplicates(subset=None, keep='first', inplace=False)
au14dups=au14full.drop_duplicates(subset=None, keep='first', inplace=False)
au15dups=au15full.drop_duplicates(subset=None, keep='first', inplace=False)
au16dups=au16full.drop_duplicates(subset=None, keep='first', inplace=False)
au17dups=au17full.drop_duplicates(subset=None, keep='first', inplace=False)
au18dups=au18full.drop_duplicates(subset=None, keep='first', inplace=False)
au19dups=au19full.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
au11dups
# Out:
#                playlist_id                                         track_name  \
# 0   3FWGHF3qH1px8xRyTExPzj                                  Party Rock Anthem
# 1   3FWGHF3qH1px8xRyTExPzj  Somebody That I Used To Know - Miami Nights 19...
# 2   3FWGHF3qH1px8xRyTExPzj  Moves Like Jagger - Studio Recording From The ...
# 3   3FWGHF3qH1px8xRyTExPzj                                   Someone Like You
# 4   3FWGHF3qH1px8xRyTExPzj                                Rolling In The Deep
# ..                     ...                                                ...
# 95  3FWGHF3qH1px8xRyTExPzj                                  Take Over Control
# 96  3FWGHF3qH1px8xRyTExPzj                                 Hold It Against Me
# 97  3FWGHF3qH1px8xRyTExPzj                                        Love On Top
# 98  3FWGHF3qH1px8xRyTExPzj                                  All Of The Lights
# 99  3FWGHF3qH1px8xRyTExPzj                                      We R Who We R
#
# ...

# %%
us11drop= us11dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us12drop= us12dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us13drop= us13dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us14drop= us14dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us15drop= us15dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us16drop= us16dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us17drop= us17dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us18drop= us18dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
us19drop= us19dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)

au11drop= au11dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au12drop= au12dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au13drop= au13dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au14drop= au14dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au15drop= au15dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au16drop= au16dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au17drop= au17dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au18drop= au18dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)
au19drop= au19dups.drop(["playlist_id","id","type", "uri", "time_signature", "track_href", "analysis_url", "date_added"], axis=1)

# %%
au11drop
# Out:
#                                            track_name          artist  \
# 0                                   Party Rock Anthem           LMFAO
# 1   Somebody That I Used To Know - Miami Nights 19...           Gotye
# 2   Moves Like Jagger - Studio Recording From The ...        Maroon 5
# 3                                    Someone Like You           Adele
# 4                                 Rolling In The Deep           Adele
# ..                                                ...             ...
# 95                                  Take Over Control        Afrojack
# 96                                 Hold It Against Me  Britney Spears
# 97                                        Love On Top         Beyoncé
# 98                                  All Of The Lights      Kanye West
# 99                                      We R Who We R           Kesha
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
us11drop.to_csv("us11.csv", index=False, encoding='utf8')
us12drop.to_csv("us12.csv", index=False, encoding='utf8')
us13drop.to_csv("us13.csv", index=False, encoding='utf8')
us14drop.to_csv("us14.csv", index=False, encoding='utf8')
us15drop.to_csv("us15.csv", index=False, encoding='utf8')
us16drop.to_csv("us16.csv", index=False, encoding='utf8')
us17drop.to_csv("us17.csv", index=False, encoding='utf8')
us18drop.to_csv("us18.csv", index=False, encoding='utf8')
us19drop.to_csv("us19.csv", index=False, encoding='utf8')

au11drop.to_csv("au11.csv", index=False, encoding='utf8')
au12drop.to_csv("au12.csv", index=False, encoding='utf8')
au13drop.to_csv("au13.csv", index=False, encoding='utf8')
au14drop.to_csv("au14.csv", index=False, encoding='utf8')
au15drop.to_csv("au15.csv", index=False, encoding='utf8')
au16drop.to_csv("au16.csv", index=False, encoding='utf8')
au17drop.to_csv("au17.csv", index=False, encoding='utf8')
au18drop.to_csv("au18.csv", index=False, encoding='utf8')
au19drop.to_csv("au19.csv", index=False, encoding='utf8')
